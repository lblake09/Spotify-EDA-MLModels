# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
spotify_df = pd.read_csv ('~/Desktop/Spring 2020/Kaagle Data Sets/top2010s.csv')
df = pd.read_csv('/Users/larceblake/Documents/Spotify Python/spotify2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  X                 title      artist        top.genre  year  \
# 0           1  1      Hey, Soul Sister       Train       neo mellow  2010
# 1           2  2  Love The Way You Lie      Eminem  detroit hip hop  2010
# 2           3  3               TiK ToK       Kesha        dance pop  2010
# 3           4  4           Bad Romance   Lady Gaga        dance pop  2010
# 4           5  5  Just the Way You Are  Bruno Mars              pop  2010
#
#    bpm  nrgy  dnce  dB  live  val  dur  acous  spch  pop gender
# 0   97    89    67  -4     8   80  217     19     4   83      M
# 1   87    93    75  -5    52   64  263     24    23   82      M
# 2  120    84    76  -3    29   71  200     10    14   80      F
# 3  119    92    70  -4     8   71  295      0     4   79      F
# 4  109    84    64  -5     9   43  221      2     4   78      M

# %%
df.describe()
# Out:
#        Unnamed: 0           X         year         bpm        nrgy  \
# count  595.000000  595.000000   595.000000  595.000000  595.000000
# mean   302.410084  302.410084  2014.605042  118.736134   70.655462
# std    174.533867  174.533867     2.609935   24.168724   16.001492
# min      1.000000    1.000000  2010.000000   43.000000    4.000000
# 25%    152.500000  152.500000  2013.000000  100.000000   61.000000
# 50%    302.000000  302.000000  2015.000000  120.000000   74.000000
# 75%    454.500000  454.500000  2017.000000  129.000000   82.000000
# max    603.000000  603.000000  2019.000000  206.000000   98.000000
#
#              dnce          dB        live         val         dur       acous  \
# count  595.000000  595.000000  595.000000  595.000000  595.000000  595.000000
# mean    64.431933   -5.485714   17.789916   52.289076  224.598319   14.332773
# std     13.112951    1.695026   13.118903   22.499318   34.217442   20.786153
# min     23.000000  -15.000000    2.000000    4.000000  134.000000    0.000000
# 25%     57.000000   -6.000000    9.000000   35.000000  202.000000    2.000000
# 50%     66.000000   -5.000000   12.000000   52.000000  220.000000    6.000000
# 75%     73.000000   -4.000000   24.000000   69.500000  239.000000   17.000000
# max     97.000000   -2.000000   74.000000   98.000000  424.000000   99.000000
#
#              spch         pop
# count  595.000000  595.000000
# mean     8.363025   67.342857
# std      7.447864   12.719590
# min      3.000000   25.000000
# 25%      4.000000   61.000000
# 50%      5.000000   69.000000
# 75%      9.000000   76.000000
# max     48.000000   99.000000

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'X', u'title', u'artist', u'top.genre', u'year', u'bpm',
#        u'nrgy', u'dnce', u'dB', u'live', u'val', u'dur', u'acous', u'spch',
#        u'pop', u'gender'],
#       dtype='object')

# %%
df_model = df[[u'bpm', u'dB', u'dur', u'pop', u'gender', u'acous', u'spch',u'live', u'val',u'nrgy', u'dnce']]

# %%
df_dum = pd.get_dummies(df_model)
df_dum
# Out:
#      bpm  dB  dur  pop  acous  spch  live  val  nrgy  dnce  gender_F  gender_M
# 0     97  -4  217   83     19     4     8   80    89    67         0         1
# 1     87  -5  263   82     24    23    52   64    93    75         0         1
# 2    120  -3  200   80     10    14    29   71    84    76         1         0
# 3    119  -4  295   79      0     4     8   71    92    70         1         0
# 4    109  -5  221   78      2     4     9   43    84    64         0         1
# 5     65  -5  214   77      4    14    11   54    86    73         0         1
rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split

X = df_dum.drop('pop', axis = 1)
y = df_dum['pop']


#80/20 train test split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 1)

# %%
len(X_train)
len(y_train)
# Out:
# 476

# %% [markdown]
# ### Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

#initialize the lm 
lm = LinearRegression()

#train the model 
lm.fit(X_train, y_train)

#prediction
y_pre = lm.predict(X_test)

#metrics
print('Coefficients:', lm.coef_)
print('Intercept:', lm.intercept_)
print('Mean absolute error (MAE): %.2f' % mean_absolute_error(y_test, y_pre))
# Out:
# ('Coefficients:', array([ 3.75520708e-02,  9.93486730e-01, -3.81351108e-02, -2.62970848e-02,
#        -2.93062219e-02, -1.48524520e-02,  1.38993704e-03, -2.07056981e-01,
#         9.29843055e-02, -3.04353618e+00,  3.04353618e+00]))
# ('Intercept:', 86.10572800700294)
# Mean absolute error (MAE): 9.07

# %%
from sklearn.model_selection import cross_val_score

np.mean(cross_val_score(lm, X_train,y_train, scoring = 'neg_mean_absolute_error', cv = 10))
# Out:
# -9.814065635940178

# %% [markdown]
# ### Lasso Regression (L1 Regularization)

# %%
from sklearn.linear_model import Lasso 

lm_las = Lasso()
lm_las.fit(X_train, y_train)
np.mean(cross_val_score(lm_las, X_train,y_train, scoring = 'neg_mean_absolute_error', cv = 10))
# Out:
# -9.85126403907391

# %% [markdown]
# ### Ridge Regression (Regularization)

# %%
from sklearn.linear_model import Ridge

lm_rid = Ridge()
lm_rid.fit(X_train, y_train)
np.mean(cross_val_score(lm_rid, X_train,y_train, scoring = 'neg_mean_absolute_error', cv = 10))
# Out:
# -9.81346819074209

# %% [markdown]
# ### Random Forrest

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth = 2, random_state = 0)
np.mean(cross_val_score(rf, X_train,y_train, scoring = 'neg_mean_absolute_error', cv = 10))
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# -9.887420039058796

# %% [markdown]
# ### Tuning RF w/ GridsearchCV

# %%
from sklearn.model_selection import GridSearchCV

params = {'n_estimators':range(10,100,10), 'criterion':('mse','mae'),'max_features':('auto','sqrt','log2')}

gs_rf = GridSearchCV(rf,params,scoring = 'neg_mean_absolute_error', cv=10)
gs_rf.fit(X_train,y_train)
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=2,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'n_estimators': [10, 20, 30, 40, 50, 60, 70, 80, 90], 'max_features': ('auto', 'sqrt', 'log2'), 'criterion': ('mse', 'mae')},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_absolute_error', verbose=0)

# %%
gs_rf.best_score_
# Out:
# -9.617997198879552

# %%
gs_rf.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mae', max_depth=2,
#            max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=30, n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
lm_pred = lm.predict(X_test)
lm_las_pred = lm_las.predict(X_test)
lm_rid_pred = lm_rid.predict(X_test)
rf_pred = gs_rf.best_estimator_.predict(X_test)

# %%
print("MLR MAE: ", mean_absolute_error(y_test,lm_pred))
print("Lasso Regression MAE: ", mean_absolute_error(y_test,lm_las_pred))
print("Ridge Regression MAE: ", mean_absolute_error(y_test,lm_rid_pred))
print("Random Forest MAE: ", mean_absolute_error(y_test, rf_pred))
# Out:
# ('MLR MAE: ', 9.072627335634118)
# ('Lasso Regression MAE: ', 9.073363614134733)
# ('Ridge Regression MAE: ', 9.073363614134733)
# ('Random Forest MAE: ', 9.08543417366947)
